# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Functional Method

# %%
# Functional Method
plt.plot(x,y,'r-')
plt.xlabel('X Label')
plt.ylabel('y Label')
plt.title('Title')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# ## Object Oriented Method

# %%
fig = plt.figure()
# left bottom width height
axes = fig.add_axes([0.1,0.1,0.8,0.8,])
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ### fig.add_axes([left, bottom, width, height])

# %%
fig = plt.figure()
#smaller figure
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

#Larger Figure
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes2.plot(y,x)
axes2.set_title('Small Plot')
axes1.set_title('Larger Plot')
# Out:
# Text(0.5, 1.0, 'Larger Plot')

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
plt.tight_layout()

# for current_ax in axes:
#     current_ax.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ### Figure Size and DPI

# %%
fig = plt.figure(figsize=(3,2), dpi = 100)
ax = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label = 'X Squared')
ax.plot(x,x**3, label = 'X Cubed')


#adding a legend
#loc = 0, makes plt choose for you 
ax.legend(loc=0)
ax.legend(loc=(0.1,0.1))

# %%
# How to save a figure
fig.savefig('my_picture.png',dpi=300)

# %% [markdown]
# ### Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
# You can use abbreviation such as lw or ls for linewidth or linestyle
ax.plot(x,y,color = 'purple',linewidth = 2,alpha = 0.5,linestyle = '--',
        marker = 'o',markersize = 20, markerfacecolor = 'green', markeredgewidth = 3)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
# You can use abbreviation such as lw or ls for linewidth or linestyle
ax.plot(x,y,color = 'purple',linewidth = 2,alpha = 0.5,linestyle = '--')
   
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
